# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family']='serif'
fig, axs = plt.subplots(1, 3, figsize=(10, 3))

axs[0].set(xlabel=r'$f$'+' predicted', ylabel=r'$f$'+' true')
axs[1].set(xlabel='width predicted', ylabel='width true')
axs[2].set(xlabel='norm predicted', ylabel='norm true')

plt.subplots_adjust(wspace=0.4)
plt.savefig(r'3Dvisualizer.png', bbox_inches='tight')
plt.show()
